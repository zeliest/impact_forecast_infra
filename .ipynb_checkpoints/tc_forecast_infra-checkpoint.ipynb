# %%
from climada_petals.hazard import TCForecast
import logging
import datetime

#today's forecast:
logging.getLogger('climada.hazard.tc_tracks_forecast').setLevel(logging.WARNING)

forecast = TCForecast()
forecast.fetch_ecmwf()
# Out:
# Processing ECMWF forecast. Date: 2023-01-04 10:59:56.968030
# ...
# Processing:  25%|██████████████████████████████████████▌                                                                                                                   | 9/36 [00:00<00:01, 15.74 files/s]
# 2023-05-04 11:00:23,205 - climada_petals.hazard.tc_tracks_forecast - WARNING - Pressure at time 39: only 1 variable value for 2 ensemble members, duplicating value to all members. This is only acceptable for lat and lon data at time 0.
# Processing:  31%|██████████████████████████████████████████████▊                                                                                                          | 11/36 [00:00<00:01, 16.63 files/s]
# 2023-05-04 11:00:23,286 - climada_petals.hazard.tc_tracks_forecast - WARNING - Pressure at time 25: only 1 variable value for 2 ensemble members, duplicating value to all members. This is only acceptable for lat and lon data at time 0.
# ...

# %%
str(datetime.datetime.now())
# Out:
# '2023-05-04 10:59:56.968030'

# %%
forecast.fetch_bufr_ftp(target_dir="/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data",remote_dir="20230311120000")
# Out:
# Download: 100%|██████████████████████████████████████████████████| 23/23 [00:04<00:00,  4.68 files/s]
# [<_io.BufferedRandom name='/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data/A_JSXX01ECEP111200_C_ECMP_20230311120000_tropical_cyclone_track_FREDDY_37p3degE_-18p1degS_bufr4.bin'>,
#  <_io.BufferedRandom name='/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data/A_JSXX02ECEP111200_C_ECMP_20230311120000_tropical_cyclone_track_70W_121p5degE_3p4degN_bufr4.bin'>,
#  <_io.BufferedRandom name='/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data/A_JSXX03ECEP111200_C_ECMP_20230311120000_tropical_cyclone_track_71W_112p9degE_3p4degN_bufr4.bin'>,
#  <_io.BufferedRandom name='/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data/A_JSXX04ECEP111200_C_ECMP_20230311120000_tropical_cyclone_track_72W_153p5degE_7p9degN_bufr4.bin'>,
# ...

# %%
tc_fcast = TCForecast()
tc_fcast.fetch_ecmwf(path='/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/forecast_data')
# Out:
# Processing: 100%|████████████████████████████████████████████████| 23/23 [00:01<00:00, 12.45 files/s]

# %%
tc_fcast.plot()
# Out:
# <GeoAxesSubplot:>

# %%
tc_fcast.data.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 tc_fcast.data.Coordinates
#
# AttributeError: 'list' object has no attribute 'Coordinates'
